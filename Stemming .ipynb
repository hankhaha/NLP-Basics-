# %% [markdown]
# # Supplemental Data Cleaning: Using Stemming

# %% [markdown]
# In the last chapter, we learned the basics of preparing our text to build the model. We learned how to **remove punctuation, tokenize, and removed stop words** to provide a clean list of words to Python. In this chapter, we're going to learn how to take our cleaning one step further, to provide the model with better information for classifying the text. We'll the introduce the concepts of **stemming** and memetizing in this chapter. Let's start with stemming. So what is stemming? The formal definition of stemming is the process of reducing inflected or derived words to their word stem or root.

# %% [markdown]
# ## Why do we care?
#
# - Reduce the corpus of words a model is exposed to
# - Explicitly correlate words with similar meanings

# %% [markdown]
# ### Test out Porter stemmer

# %%
import nltk

ps = nltk.PorterStemmer()

# %%
dir(ps)
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'unicode_repr',
#  'vowels']

# %%
# we can find that these three words can be treated as the same word now
print(ps.stem('grows'))
print(ps.stem('growing'))
print(ps.stem('grow'))
# Out:
# grow
# grow
# grow

# %%
# stemmer can actually tell the first two are different than the last one 
print(ps.stem('run'))
print(ps.stem('running'))
print(ps.stem('runner'))

# %% [markdown]
# ### Read in raw text

# %%
import pandas as pd
import re
import string
pd.set_option('display.max_colwidth', 100)

# store the stop words for use when we clean up the data
stopwords = nltk.corpus.stopwords.words('english')

data = pd.read_csv("SMSSpamCollection.tsv", sep='\t')
data.columns = ['label', 'body_text']

data.head()
# Out:
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...

# %% [markdown]
# ### Clean up text

# %%
# We put together three functions we built previously into one to clean up the data
def clean_text(text):
    
    # remove punctuation
    text = "".join([word for word in text if word not in string.punctuation])
    # tokenize it 
    tokens = re.split('\W+', text)
    # remove stopwords
    text = [word for word in tokens if word not in stopwords]
    return text

data['body_text_nostop'] = data['body_text'].apply(lambda x: clean_text(x.lower()))

data.head(10)
# Out:
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
# 5  spam
# 6  spam
# 7   ham
# 8  spam
# 9  spam
#
#                                                                                              body_text  \
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...
# 5  WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To c...
# 6  Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with came...
# ...

# %% [markdown]
# ### Stem text

# %%
def stemming (tokenized_text):
    text = [ps.stem(word) for word in tokenized_text]
    return text

data['body_text_stemmed'] = data['body_text_nostop'].apply(lambda x:stemming(x))

data.head(10)
# Out:
#   label  \
# 0  spam
# 1   ham
# 2   ham
# 3   ham
# 4   ham
# 5  spam
# 6  spam
# 7   ham
# 8  spam
# 9  spam
#
#                                                                                              body_text  \
# 0  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 1                                        Nah I don't think he goes to usf, he lives around here though
# 2                        Even my brother is not like to speak with me. They treat me like aids patent.
# 3                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
# 4  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...
# 5  WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To c...
# 6  Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with came...
# ...
